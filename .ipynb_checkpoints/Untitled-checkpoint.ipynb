# %%
import requests
import json

# %%
# i = requests.get("https://api.covid19api.com/dayone/country/south-korea/status/confirmed/live")

i = requests.get("https://covidtracking.com/api/counties")

# %%
j = i.json()

# %%
print(json.dumps(j, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "Cases": 1,
#         "City": "",
#         "CityCode": "",
#         "Country": "Korea (South)",
#         "CountryCode": "KR",
#         "Date": "2020-01-22T00:00:00Z",
#         "Lat": "35.91",
#         "Lon": "127.77",
#         "Province": "",
#         "Status": "confirmed"
#     },
#     {
#         "Cases": 1,
#         "City": "",
#         "CityCode": "",
#         "Country": "Korea (South)",
#         "CountryCode": "KR",
#         "Date": "2020-01-23T00:00:00Z",
#         "Lat": "35.91",
#         "Lon": "127.77",
#         "Province": "",
#         "Status": "confirmed"
#     },
#     {
#         "Cases": 2,
#         "City": "",
#         "CityCode": "",
#         "Country": "Korea (South)",
#         "CountryCode": "KR",
#         "Date": "2020-01-24T00:00:00Z",
#         "Lat": "35.91",
#         "Lon": "127.77",
#         "Province": "",
#         "Status": "confirmed"
#     },
#     {
#         "Cases": 2,
#         "City": "",
# ...
